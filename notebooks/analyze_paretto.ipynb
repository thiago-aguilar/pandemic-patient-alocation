# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np
from pareto_generator import generate_pareto

# %%
fist_pareto_df = pd.read_csv('../results_pareto/pareto_curve.csv')
generate_pareto(fist_pareto_df, title='first_pareto')
# Out:
# Hipervolume : 600078.5994463963
# Delta_metric: 0.9065571601237079

# %%
fist_pareto_df
# Out:
#     Unnamed: 0          obj1       obj2
# 0            0  3.750562e+06  43.320000
# 1            1  3.747525e+06  43.460000
# 2            2  3.744450e+06  43.460000
# 3            3  3.741376e+06  43.460000
# 4            4  3.738301e+06  43.460000
# 5            5  3.735227e+06  43.460000
# 6            6  3.732152e+06  43.460000
# 7            7  3.729078e+06  43.460000
# 8            8  3.726003e+06  43.460000
# 9            9  3.722929e+06  43.460000
# 10          10  3.719855e+06  43.460000
# 11          11  3.716780e+06  43.460000
# 12          12  3.713706e+06  43.460000
# 13          13  3.710631e+06  43.460000
# 14          14  3.707557e+06  43.460000
# 15          15  3.704482e+06  43.460000
# 16          16  3.701408e+06  43.660000
# 17          17  3.698333e+06  43.660000
# 18          18  3.695259e+06  45.650000
# 19          19  3.692184e+06  48.330000
# 20          20  3.692184e+06  48.330483
# 21          21  3.694293e+06  48.066796
# 22          22  3.694293e+06  47.803110
# 23          23  3.694293e+06  47.539423
# 24          24  3.694293e+06  47.275736
# 25          25  3.694293e+06  47.012049
# 26          26  3.694293e+06  46.748362
# 27          27  3.694293e+06  46.484675
# 28          28  3.694293e+06  46.220989
# 29          29  3.694293e+06  45.957302
# 30          30  3.694293e+06  45.693615
# 31          31  3.697595e+06  45.429928
# 32          32  3.697595e+06  45.166241
# 33          33  3.697595e+06  44.902554
# 34          34  3.697595e+06  44.638867
# 35          35  3.697595e+06  44.375181
# 36          36  3.697595e+06  44.111494
# 37          37  3.697595e+06  43.847807
# 38          38  3.702376e+06  43.584120
# 39          39  3.750562e+06  43.320433
# 40          40  3.692147e+06  48.330000
# 41          41  3.750562e+06  43.320000

# %%
fist_pareto_df = pd.read_csv('../results_pareto/pareto_curve.csv')
generate_pareto(fist_pareto_df, title='first_pareto')
# Out:
# Hipervolume : 326889.8787047844
# Delta_metric: 0.9568622990024255

# %%
obj1_min = 18525366.001666658
obj1_max = 19271937.46499998
eps_values = np.linspace(obj1_min, obj1_max, 10)
eps_values
# Out:
# array([18525366.00166666, 18608318.38648147, 18691270.77129629,
#        18774223.1561111 , 18857175.54092591, 18940127.92574073,
#        19023080.31055554, 19106032.69537035, 19188985.08018517,
#        19271937.46499998])

# %%
obj2_max = 332.64
obj2_min = 263.31
